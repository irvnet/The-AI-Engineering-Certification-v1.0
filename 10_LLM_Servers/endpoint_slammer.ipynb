# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %%
import os
print(bool(os.environ.get("FIREWORKS_API_KEY")))
print(len(os.environ.get("FIREWORKS_API_KEY", "")))
# Out:
# True
# 25

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# It’s a classic tongue‑twister, not a scientific inquiry, but the “official” estimate that pops up in pop‑culture is that a woodchuck could chuck **about 700 pounds of wood** if it had the motivation to.
# That number comes from wildlife biologist Richard Thomas in 1988, who measured the amount of earth a woodchuck can move when digging its burrow and then applied that same effort to wood. In reality, woodchucks (groundhogs) don’t actually chuck wood— they’re burrow‑builders, not lumberjacks. So a more genuine answer is: a woodchuck would chuck as much wood as a woodchuck could if it could chuck wood— which, in practice, is none at all! 🚜💨

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 13: It’s always been a classic brain‑twist whether a wood‑chuck ...
# Response 10: In the playful spirit of the old tongue‑twister, the “answer...
# Response 18: A playful answer often goes like this:
#
# > **“A woodchuck wou...
# Response 12: The classic tongue‑teller goes: **“How much wood could a woo...
# Response 24: A classic tongue‑twister, the answer usually goes something ...
# Response 9: A classic answer is: “A wood‑chuck would chuck as much wood ...
# Response 22: Ah, the age‑old riddle that tickles tongues and tickles toes...
# Response 6: The classic tongue‑twister is a bit of playful hyperbole—woo...
# Response 3: It’s a classic tongue‑twister more than a serious question, ...
# Response 17: A woodchuck would probably chuck on the order of **700 pound...
# Response 21: A wood‑chuck (ground squirrel) isn’t really built to “chuck”...
# Response 23: A classic answer is that a wood‑chuck would chuck as much wo...
# Response 16: A classic tongue‑twister with no hard math behind it, but hu...
# Response 8: **Answer**
#
# The tongue‑twister almost has an answer of its o...
# Response 4: A 1978 study by wildlife biologist Richard Thomas found that...
# Response 5: The classic tongue‑twister usually comes with the punchline ...
# Response 7: A woodchuck would chuck about 700 pounds of wood per day—rou...
# Response 15: **Answer (classic & a dash of science)**
#
# > "A wood‑chuck ...
# Response 20: The classic tongue‑twister doesn’t actually have a single, s...
# Response 2: A woodchuck could chuck roughly 700 pounds of wood, accordin...
# Response 19: The classic tongue‑twister has baffled folks for ages, but s...
# Response 1: The question isn’t a puzzle to be solved with arithmetic—it’...
# Response 14: A classic rhyme or a clever riddle—both! The most widely‑quo...
# Response 11: **Short answer**
# > **— About 700 pounds of wood (≈ 317 kg)...
